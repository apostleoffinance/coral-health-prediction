# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns



# %store -r core_coral_env

core_coral_env.head()
# Out:
#    StationID       Date  Pseudopterogorgia_americana  Total_Octocorals  \
# 0        321 2011-06-08                         23.8               9.0
# 1        321 2011-06-08                         23.8               9.0
# 2        321 2011-06-08                         23.8               9.0
# 3        321 2011-06-08                         23.8               9.0
# 4        321 2011-06-08                         23.8               9.0
#
#    Siderastrea_siderea  Siderastrea_siderea_scor_lta  \
# 0                 18.0                        7324.5
# 1                 18.0                        7324.5
# 2                 18.0                        7324.5
# 3                 18.0                        7324.5
# 4                 18.0                        7324.5
#
#    Siderastrea_siderea_scor_density               sciName  Count  SiteID  \
# 0                               1.8  Dichocoenia stokesii    4.0    32.0
# ...
